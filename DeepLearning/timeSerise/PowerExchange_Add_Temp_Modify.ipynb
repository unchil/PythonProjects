# %%
import pandas as pd

# %%
data_dir = '/Volumes/Data/Row_Data'
load_file = 'kpx_power_demand_addTemp_2023.csv'

# %%
url = f'{data_dir}/{load_file}'
df_data = pd.read_csv(url,  parse_dates=['date_time'], index_col = 'date_time' )
df_data
# Out:
#                      value            base_time  temp  weekday  month  \
# date_time
# 2023-01-01 00:00:00  64322  2023-01-01 00:00:00    -3        6      1
# 2023-01-01 01:00:00  61879  2023-01-01 01:00:00    -3        6      1
# 2023-01-01 02:00:00  60133  2023-01-01 02:00:00    -3        6      1
# 2023-01-01 03:00:00  59170  2023-01-01 03:00:00    -4        6      1
# 2023-01-01 04:00:00  58813  2023-01-01 04:00:00    -4        6      1
# ...                    ...                  ...   ...      ...    ...
# 2023-12-31 19:00:00  62902  2023-12-31 19:00:00     1        6     12
# 2023-12-31 20:00:00  62061  2023-12-31 20:00:00     0        6     12
# 2023-12-31 21:00:00  61403  2023-12-31 21:00:00     0        6     12
# 2023-12-31 22:00:00  61891  2023-12-31 22:00:00    -1        6     12
# 2023-12-31 23:00:00  62125  2023-12-31 23:00:00    -1        6     12
#
#                             day  hr  temp_boundary
# date_time
# 2023-01-01 00:00:00  2023-01-01   0              1
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8760 entries, 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Data columns (total 53 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   value            8760 non-null   int64
#  1   base_time        8760 non-null   object
#  2   temp             8760 non-null   int64
#  3   day              8760 non-null   object
#  4   month_1          8760 non-null   bool
#  5   month_2          8760 non-null   bool
#  6   month_3          8760 non-null   bool
#  7   month_4          8760 non-null   bool
#  8   month_5          8760 non-null   bool
#  9   month_6          8760 non-null   bool
#  10  month_7          8760 non-null   bool
#  11  month_8          8760 non-null   bool
#  12  month_9          8760 non-null   bool
#  13  month_10         8760 non-null   bool
#  14  month_11         8760 non-null   bool
#  15  month_12         8760 non-null   bool
# ...

# %%
df_data = pd.get_dummies(df_data, columns = ['month', 'weekday', 'hr', 'temp_boundary'])
df_data = df_data.drop( columns=['base_time', 'temp', 'day'] )
df_data
# Out:
#                      value  month_1  month_2  month_3  month_4  month_5  \
# date_time
# 2023-01-01 00:00:00  64322     True    False    False    False    False
# 2023-01-01 01:00:00  61879     True    False    False    False    False
# 2023-01-01 02:00:00  60133     True    False    False    False    False
# 2023-01-01 03:00:00  59170     True    False    False    False    False
# 2023-01-01 04:00:00  58813     True    False    False    False    False
# ...                    ...      ...      ...      ...      ...      ...
# 2023-12-31 19:00:00  62902    False    False    False    False    False
# 2023-12-31 20:00:00  62061    False    False    False    False    False
# 2023-12-31 21:00:00  61403    False    False    False    False    False
# 2023-12-31 22:00:00  61891    False    False    False    False    False
# 2023-12-31 23:00:00  62125    False    False    False    False    False
#
#                      month_6  month_7  month_8  month_9  ...  hr_20  hr_21  \
# ...

# %%
df_data.info
