# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/unchil/PythonProjects/timeSerise

# %%
df_weather_data = pd.read_csv('./data/london_weather.csv',  parse_dates=['date'])
df_weather_data.head()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0 1979-01-01          2.0       7.0              52.0       2.3       -4.1
# 1 1979-01-02          6.0       1.7              27.0       1.6       -2.6
# 2 1979-01-03          5.0       0.0              13.0       1.3       -2.8
# 3 1979-01-04          8.0       0.0              13.0      -0.3       -2.6
# 4 1979-01-05          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
df_weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  datetime64[ns]
#  1   cloud_cover       15322 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15322 non-null  float64
#  4   max_temp          15335 non-null  float64
#  5   mean_temp         15305 non-null  float64
#  6   min_temp          15339 non-null  float64
#  7   precipitation     15335 non-null  float64
#  8   pressure          15337 non-null  float64
#  9   snow_depth        13900 non-null  float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 1.2 MB

# %%
df_weather_data.describe()
# Out:
#                       date   cloud_cover      sunshine  global_radiation  \
# count                15341  15322.000000  15341.000000      15322.000000
# mean   2000-01-01 00:00:00      5.268242      4.350238        118.756951
# min    1979-01-01 00:00:00      0.000000      0.000000          8.000000
# 25%    1989-07-02 00:00:00      4.000000      0.500000         41.000000
# 50%    2000-01-01 00:00:00      6.000000      3.500000         95.000000
# 75%    2010-07-02 00:00:00      7.000000      7.200000        186.000000
# max    2020-12-31 00:00:00      9.000000     16.000000        402.000000
# std                    NaN      2.070072      4.028339         88.898272
#
#            max_temp     mean_temp      min_temp  precipitation       pressure  \
# count  15335.000000  15305.000000  15339.000000   15335.000000   15337.000000
# mean      15.388777     11.475511      7.559867       1.668634  101536.605594
# ...

# %%
df_weather = df_weather_data[ df_weather_data.date.between('2012-01-01', '2013-12-31')]

# %%
df_weather[df_weather.precipitation > 0]
# Out:
#             date  cloud_cover  sunshine  global_radiation  max_temp  \
# 12053 2012-01-01          7.0       0.0              13.0      11.9
# 12054 2012-01-02          1.0       6.3              49.0      12.6
# 12055 2012-01-03          5.0       1.4              25.0      11.7
# 12056 2012-01-04          4.0       0.4              18.0      11.0
# 12057 2012-01-05          4.0       3.5              37.0      10.6
# ...          ...          ...       ...               ...       ...
# 12777 2013-12-25          3.0       1.4              24.0      11.2
# 12778 2013-12-26          6.0       1.0              22.0      10.8
# 12781 2013-12-29          1.0       6.3              48.0      10.5
# 12782 2013-12-30          4.0       1.7              27.0      10.9
# 12783 2013-12-31          5.0       0.0              13.0      11.4
#
#        mean_temp  min_temp  precipitation  pressure  snow_depth
# 12053       12.2      11.3            7.2  100480.0         0.0
# ...

# %%
df_weather
# Out:
#             date  cloud_cover  sunshine  global_radiation  max_temp  \
# 12053 2012-01-01          7.0       0.0              13.0      11.9
# 12054 2012-01-02          1.0       6.3              49.0      12.6
# 12055 2012-01-03          5.0       1.4              25.0      11.7
# 12056 2012-01-04          4.0       0.4              18.0      11.0
# 12057 2012-01-05          4.0       3.5              37.0      10.6
# ...          ...          ...       ...               ...       ...
# 12779 2013-12-27          4.0       1.0              22.0       8.8
# 12780 2013-12-28          2.0       4.5              40.0      10.5
# 12781 2013-12-29          1.0       6.3              48.0      10.5
# 12782 2013-12-30          4.0       1.7              27.0      10.9
# 12783 2013-12-31          5.0       0.0              13.0      11.4
#
#        mean_temp  min_temp  precipitation  pressure  snow_depth
# 12053       12.2      11.3            7.2  100480.0         0.0
# ...

# %%
df_weather.index = df_weather.date
df_weather_new = df_weather[[ 'cloud_cover', 'max_temp', 'mean_temp', 'min_temp', 'precipitation', 'snow_depth']]
df_weather_new.to_csv('./data/london_weather_modify.csv')

# %%
a = df_weather.groupby(['cloud_cover']).agg({'date':'count'})
a
# Out:
#              date
# cloud_cover
# 0.0            47
# 1.0            54
# 2.0            51
# 3.0            63
# 4.0           102
# 5.0            93
# 6.0           116
# 7.0           107
# 8.0            97

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='cloud_cover', data=df_weather, hue='cloud_cover',  palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='cloud_cover',y = 'snow_depth' ,data=df_weather, hue='cloud_cover',  palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='cloud_cover',y = 'precipitation' ,data=df_weather, hue='cloud_cover',  palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='cloud_cover',y = 'mean_temp' ,data=df_weather, hue='cloud_cover',  palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='cloud_cover', y='sunshine', data = df_weather, hue='cloud_cover', palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='cloud_cover', y='global_radiation', data = df_weather, hue='cloud_cover', palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='cloud_cover', y='mean_temp', data = df_weather, hue='cloud_cover', palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='cloud_cover', y='max_temp', data = df_weather, hue='cloud_cover', palette=sns.color_palette('hls', 9))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='cloud_cover', y='min_temp', data = df_weather, hue='cloud_cover', palette=sns.color_palette('hls', 9))
plt.show()

# %%
df_weather.describe().columns
# Out:
# Index(['date', 'cloud_cover', 'sunshine', 'global_radiation', 'max_temp',
#        'mean_temp', 'min_temp', 'precipitation', 'pressure', 'snow_depth'],
#       dtype='object')

# %%
num_vars = [ 'cloud_cover', 'sunshine', 'global_radiation', 'max_temp',
       'mean_temp', 'min_temp', 'precipitation', 'pressure', 'snow_depth']

sns.heatmap(df_weather[num_vars].corr(), annot=True)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))

sns.boxplot(x='precipitation',  data = df_weather)

plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(x='snow_depth',  data = df_weather)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(x='max_temp',  data = df_weather)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
axs = fig.subplot_mosaic([[ 'KWH']])

axs['KWH'].set_title('KWH')
sns.boxplot(x='KWH',  data =  c , ax=axs['KWH'])

plt.show()

# %%
b = c.groupby([ 'year', 'Date']).agg({'KWH':['count', 'min', 'max', 'mean']})
b
# Out:
#                   KWH
#                 count    min     max       mean
# year Date
# 2012 2012-01-01   347  0.445  60.159  12.536493
#      2012-01-02   347  0.463  65.824  12.864265
#      2012-01-03   347  0.464  64.652  12.893674
#      2012-01-04   347  0.838  68.020  12.829674
#      2012-01-05   347  0.764  63.598  12.980193
# ...               ...    ...     ...        ...
# 2013 2013-12-27   347  0.536  64.658  12.067254
#      2013-12-28   347  0.550  72.353  11.930291
#      2013-12-29   347  0.538  62.881  12.591813
#      2013-12-30   347  0.354  54.214  12.375937
#      2013-12-31   347  0.541  81.308  12.414700
#
# [731 rows x 4 columns]

# %%
d =c.groupby([  'Date']).agg({'KWH':['count', 'min', 'max', 'mean']})
d
# Out:
#              KWH
#            count    min     max       mean
# Date
# 2012-01-01   347  0.445  60.159  12.536493
# 2012-01-02   347  0.463  65.824  12.864265
# 2012-01-03   347  0.464  64.652  12.893674
# 2012-01-04   347  0.838  68.020  12.829674
# 2012-01-05   347  0.764  63.598  12.980193
# ...          ...    ...     ...        ...
# 2013-12-27   347  0.536  64.658  12.067254
# 2013-12-28   347  0.550  72.353  11.930291
# 2013-12-29   347  0.538  62.881  12.591813
# 2013-12-30   347  0.354  54.214  12.375937
# 2013-12-31   347  0.541  81.308  12.414700
#
# [731 rows x 4 columns]

# %%
d.KWH[['min', 'max','mean']]
# Out:
#               min     max       mean
# Date
# 2012-01-01  0.445  60.159  12.536493
# 2012-01-02  0.463  65.824  12.864265
# 2012-01-03  0.464  64.652  12.893674
# 2012-01-04  0.838  68.020  12.829674
# 2012-01-05  0.764  63.598  12.980193
# ...           ...     ...        ...
# 2013-12-27  0.536  64.658  12.067254
# 2013-12-28  0.550  72.353  11.930291
# 2013-12-29  0.538  62.881  12.591813
# 2013-12-30  0.354  54.214  12.375937
# 2013-12-31  0.541  81.308  12.414700
#
# [731 rows x 3 columns]

# %%
e = d.KWH[['min', 'max','mean']]

e
# Out:
#               min     max       mean
# Date
# 2012-01-01  0.445  60.159  12.536493
# 2012-01-02  0.463  65.824  12.864265
# 2012-01-03  0.464  64.652  12.893674
# 2012-01-04  0.838  68.020  12.829674
# 2012-01-05  0.764  63.598  12.980193
# ...           ...     ...        ...
# 2013-12-27  0.536  64.658  12.067254
# 2013-12-28  0.550  72.353  11.930291
# 2013-12-29  0.538  62.881  12.591813
# 2013-12-30  0.354  54.214  12.375937
# 2013-12-31  0.541  81.308  12.414700
#
# [731 rows x 3 columns]

# %%
e.to_csv('./data/london_energy_modify.csv')

# %%
e_t = e.groupby(e.index.month).mean()
e_t
# Out:
#            min        max       mean
# Date
# 1     0.709242  75.597323  13.031559
# 2     0.825702  64.848439  12.981028
# 3     0.806532  63.219677  11.813825
# 4     0.644550  58.269250  10.718793
# 5     0.743145  49.194403   9.629457
# 6     0.665567  51.245583   9.000475
# 7     0.701710  48.264823   8.668778
# 8     0.775371  45.331468   8.471206
# 9     0.788417  45.371633   9.207766
# 10    0.706742  53.744677  10.180867
# 11    0.954517  76.804500  11.779139
# 12    0.738694  73.467548  12.739165

# %%
fig = plt.figure(figsize=(16,4))
axs = fig.subplot_mosaic([['KWH']])

axs['KWH'].set_title('KWH')

sns.lineplot(data = e_t,  ax=axs['KWH'])
# Out:
# <Axes: label='KWH', title={'center': 'KWH'}, xlabel='Date'>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='weekday', y='traffic_volume', data = df_traffic_temp, hue='weekday', palette=sns.color_palette('hls', 7))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns




fig = plt.figure(figsize=(16,4))
axs = fig.subplot_mosaic([['KWH']])

axs['KWH'].set_title('KWH')

sns.lineplot(data = e.loc['2012-01-01':'2013-12-31'],  ax=axs['KWH'])
# Out:
# <Axes: label='KWH', title={'center': 'KWH'}, xlabel='Date'>

# %%
df_energy_data['date'] = df_energy_data.Date.dt.date
df_energy_data['month'] = df_energy_data.Date.dt.month
df_energy_data['year'] = df_energy_data.Date.dt.year

# %%
df_energy_data = pd.read_csv('./data/london_energy_modify.csv',  parse_dates=['Date'])
df_energy_data.head()
# Out:
#         Date    min     max       mean
# 0 2012-01-01  0.445  60.159  12.536493
# 1 2012-01-02  0.463  65.824  12.864265
# 2 2012-01-03  0.464  64.652  12.893674
# 3 2012-01-04  0.838  68.020  12.829674
# 4 2012-01-05  0.764  63.598  12.980193
